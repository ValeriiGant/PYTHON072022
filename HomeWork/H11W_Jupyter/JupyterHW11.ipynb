# %% [markdown]
# ## Знакомство с языком Python (семинары)
#
# ### Урок 11. Jupyter Notebook и несколько слов об аналитике
#
# ## f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# * Определить корни
#
# * Найти интервалы, на которых функция возрастает
#
# * Найти интервалы, на которых функция убывает
#
# * Построить график
#
# * Вычислить вершину
#
# * Определить промежутки, на котором f > 0
#
# * Определить промежутки, на котором f < 0

# %%
import sympy
import numpy as np
from sympy.plotting import plot
from sympy import symbols

# %% [markdown]
# ### Построим график заданной функции:

# %%
x = symbols('x')
plot(-12*x**4*sympy.sin(sympy.cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, (x, -100, 100))

# %% [markdown]
# * Интервалов возрастания и убывания бесконечное множество.

# %% [markdown]
# ### Найдем корни:

# %%
sympy.solveset(sympy.Eq(-12*x**4*sympy.sin(sympy.cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), x)
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes)

# %% [markdown]
# * Корней бесконечное множество

# %% [markdown]
# * Промежутков где f > 0 и f < 0 бесконечное множество.
# ## Для примера определим промежутки, на котором f > 0 и f < 0 в диапазоне -10 < x < 10 c с шагом 1.

# %%
x = np.arange(-10, 10, 1)
func = -12*x**4 * (np.sin(np.cos(x))) - 18*x**3 + 5*x**2 + 10*x - 30

pos_list = []
neg_list = []

for i in x:
    res = -12*i**4 * (np.sin(np.cos(i))) - 18*i**3 + 5*i**2 + 10*i - 30
    if res > 0:
        pos_list.append(res)
    else:
        neg_list.append(res)

print(f'f > 0 в интервале: \n{pos_list[-1]} --> {pos_list[0]}\n')
print(pos_list)
print(f'\nf < 0 в интервале:\n{neg_list[0]} --> {neg_list[-1]}\n')
print(neg_list)
# Out:
# f > 0 в интервале:
# 49556.7845886376 --> 107652.76951248452
#
# [107652.76951248452, 75620.7845886376, 16552.410757701822, 195.94986923604483, 3030.0310056164317, 1283.613249414674, 191.61391753963503, 371.6132494146741, 806.0310056164317, 49556.7845886376]
#
# f < 0 в интервале:
# -13402.491276575198 --> -1719.5892422981788
#
# [-13402.491276575198, -8763.585937318787, -23.17274310228259, -30.0, -39.17274310228259, -56.386082460364975, -4204.050130763955, -16419.585937318785, -25610.491276575198, -1719.5892422981788]
